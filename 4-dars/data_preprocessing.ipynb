# %%
import pandas as pd
df = pd.read_csv('country_metadata.csv')

# %% [markdown]
# Problem Solving for Operations and Conditions

# %%
# Juft yoki toq
# a=10

# if a % 2 == 0:
#     print("Juft")
# else:
#     print("Toq")
    
# # musbat yoki manfiy

# b = -10
# if b<0:
#     print("Manfiy")
# elif b > 0 :
#     print("Musbat")
# else:
#     print("Nol")
# a = 30
# b = 45
# c = 111

# if a >= b and a >= c:
#     print(a)
# elif b >= a and b >= c:
#     print(b)
# else:
#     print(c)
    
# num = 30

# if num % 3 == 0 and num % 5 == 0:
#     print("Divisible by both")
# elif num % 3 == 0:
#     print("Divisible by 3")
# elif num % 5 == 0:
#     print("Divisible by 5")
# else:
#     print("Not divisible by 3 or 5")

# %%
df.head()
# Out:
#   country_code country_name iso3  \
# 0          ABW        Aruba  ABW
# 1          AFG  Afghanistan  AFG
# 2          AGO       Angola  AGO
# 3          ALB      Albania  ALB
# 4          AND      Andorra  AND
#
#                                               region         income_group  \
# 0                          Latin America & Caribbean          High income
# 1  Middle East, North Africa, Afghanistan & Pakistan           Low income
# 2                                 Sub-Saharan Africa  Lower middle income
# 3                              Europe & Central Asia  Upper middle income
# 4                              Europe & Central Asia          High income
#
#    latitude  longitude
# 0  12.51670   -70.0167
# 1  34.52280    69.1761
# 2  -8.81155    13.2420
# 3  41.33170    19.8172
# 4  42.50750     1.5218

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_code  217 non-null    str
#  1   country_name  217 non-null    str
#  2   iso3          217 non-null    str
#  3   region        217 non-null    str
#  4   income_group  217 non-null    str
#  5   latitude      211 non-null    float64
#  6   longitude     211 non-null    float64
# dtypes: float64(2), str(5)
# memory usage: 12.0 KB

# %% [markdown]
# KERAKSIZ USTUNLARNI TASHLAB YUBORISH

# %%
df.drop('country_code',axis=1,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_name  217 non-null    str
#  1   iso3          217 non-null    str
#  2   region        217 non-null    str
#  3   income_group  217 non-null    str
#  4   latitude      211 non-null    float64
#  5   longitude     211 non-null    float64
# dtypes: float64(2), str(4)
# memory usage: 10.3 KB

# %%
df.isnull().sum()
# Out:
# country_name    0
# iso3            0
# region          0
# income_group    0
# latitude        6
# longitude       6
# dtype: int64

# %% [markdown]
# MEAN ORQALI O'CHIRISH

# %%
df['latitude'].fillna({'latitude':df['latitude'].mean()},inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8032\345167252.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['latitude'].fillna({'latitude':df['latitude'].mean()},inplace=True)
# 0      12.51670
# 1      34.52280
# 2      -8.81155
# 3      41.33170
# 4      42.50750
#          ...
# 212    42.56500
# 213    15.35200
# ...

# %%
df.isnull().sum()
# Out:
# country_name    0
# iso3            0
# region          0
# income_group    0
# latitude        0
# longitude       6
# dtype: int64

# %% [markdown]
# MODE ORQALI TO'LDIRISH

# %%
# df['longitude'] = df['longitude'].fillna(df['longitude'].mode()[0],inplace=True)

# %%
# df.isnull().sum()

# %% [markdown]
# MEDIAN USULI BILAN TO'LDIRISH

# %%
# df['longitude'] = df['longitude'].fillna(df['longitude'].median(),inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8032\2732135962.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['longitude'] = df['longitude'].fillna(df['longitude'].median(),inplace=True)

# %%
# df.isnull().sum()
# Out:
# country_name    0
# iso3            0
# region          0
# income_group    0
# latitude        0
# longitude       0
# dtype: int64

# %% [markdown]
# FIXED USULI BILAN

# %%
# df['longitude'] = df['longitude'].fillna(123.233,inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8032\3357886151.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['longitude'] = df['longitude'].fillna(123.233,inplace=True)

# %%
# df.isnull().sum()
# Out:
# country_name    0
# iso3            0
# region          0
# income_group    0
# latitude        0
# longitude       0
# dtype: int64
