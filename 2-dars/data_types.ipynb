# %% [markdown]
# Data Types

# %%
#int
#float
#str
#Boolean

# %%
# int
a = 3
type(a)
# Out:
# int

# %%
#float
b = 4.9
type(b)
# Out:
# float

# %%
#str
ism = 'Dadaxon'
type(ism)
# Out:
# str

# %%
age = '20'
type(age)
# Out:
# str

# %%
#boolean

print(1>4)
# Out:
# False

# %%
#boolean
text = 'She loves you'
print(text is int)
# Out:
# False

# %%
text1 = "I don't know"
print(text1 is not int)
# Out:
# True

# %% [markdown]
# INDEXING

# %%
name = 'dadakhon'
indx_0 = name[0]
print(indx_0)
# Out:
# d

# %% [markdown]
# OPERATIONS

# %%
#math operators
# +,-,*,**,
a = 4
b = 3

print(a+b)
print(a-b)
print(a*b)
print(a**b)
# Out:
# 7
# 1
# 12
# 64

# %%
#math operations %,//,/

a = 20
b = 4
print(a%b)
print(a/b)
print(a//b)
# Out:
# 0
# 5.0
# 5

# %% [markdown]
# LOGIC OPERATORS

# %%
# LOGIC OPERATORS
# and => ikkala shart ham bajarilsa keyin TRUE
# or => bitta shart bajarilsa yetadi TRUE
text = 'Dadaxon'
print(1<5 and 5<10)
print(text == 'Dadaxon' or text == 'Dadakhon')
# Out:
# True
# False

# %% [markdown]
# HOMEWORKS

# %%
#TASK 1:
name = 'Dadaxon'
first_letter = name[0]
last_letter = name[-1]
print(f'Boshi: {first_letter}')
print(f'Oxirgi: {last_letter}')
# Out:
# Boshi: D
# Oxirgi: n

# %%
# TASK 2:
son = 20
print(son >0)
print(son % 2 ==0)
# Out:
# True
# True

# %%
# TASK 3:

ism = "Akbar"
last_two_words = ism[-2]
print(last_two_words)

# TASK 4:

number = -29
print(number > 0)
print(number % 2 !=0)
