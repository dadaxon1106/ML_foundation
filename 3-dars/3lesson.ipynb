# %% [markdown]
# DATA BILAN TANISHUV

# %%
import pandas as pd

# %%
df = pd.read_csv('ai-impact-jobs-layoff-risk-dataset.csv')
df
# Out:
#        Age Education_Level  Years_of_Experience       Industry  \
# 0       59        Master's                    6        Finance
# 1       44        Master's                   14  Manufacturing
# 2       36      Bachelor's                    7         Retail
# 3       27      Bachelor's                    6        Finance
# 4       49     High School                   12        Finance
# ...    ...             ...                  ...            ...
# 19995   56      Bachelor's                   10         Retail
# 19996   43      Bachelor's                    9  Manufacturing
# 19997   28     High School                    7        Telecom
# 19998   46      Bachelor's                    3  Manufacturing
# 19999   36      Bachelor's                    5         Retail
#
#                     Job_Role Company_Size Job_Level  Routine_Task_Percentage  \
# 0                 Accountant       Medium     Entry                       84
# ...

# %%
df.head()
# Out:
#    Age Education_Level  Years_of_Experience       Industry  \
# 0   59        Master's                    6        Finance
# 1   44        Master's                   14  Manufacturing
# 2   36      Bachelor's                    7         Retail
# 3   27      Bachelor's                    6        Finance
# 4   49     High School                   12        Finance
#
#                 Job_Role Company_Size Job_Level  Routine_Task_Percentage  \
# 0             Accountant       Medium     Entry                       84
# 1  Production Supervisor        Small     Entry                       30
# 2          Store Manager       Medium    Senior                       12
# 3                Auditor        Large     Entry                       90
# 4                Auditor        Small     Entry                       49
#
#    Creativity_Requirement  Human_Interaction_Level AI_Adoption_Level  \
# 0                      21                       94            Medium
# ...

# %%
df.tail()
# Out:
#        Age Education_Level  Years_of_Experience       Industry  \
# 19995   56      Bachelor's                   10         Retail
# 19996   43      Bachelor's                    9  Manufacturing
# 19997   28     High School                    7        Telecom
# 19998   46      Bachelor's                    3  Manufacturing
# 19999   36      Bachelor's                    5         Retail
#
#                     Job_Role Company_Size Job_Level  Routine_Task_Percentage  \
# 19995        Sales Associate        Small     Entry                       29
# 19996  Production Supervisor       Medium     Entry                       87
# 19997     Support Specialist       Medium     Entry                       91
# 19998       Quality Engineer       Medium    Senior                       76
# 19999          Store Manager       Medium       Mid                       45
#
#        Creativity_Requirement  Human_Interaction_Level AI_Adoption_Level  \
# ...

# %%
df.nunique()
# Out:
# Age                            40
# Education_Level                 4
# Years_of_Experience            27
# Industry                        8
# Job_Role                       24
# Company_Size                    3
# Job_Level                       3
# Routine_Task_Percentage        85
# Creativity_Requirement        101
# Human_Interaction_Level        80
# AI_Adoption_Level               3
# Number_of_AI_Tools_Used        11
# AI_Usage_Hours_Per_Week        31
# Tasks_Automated_Percentage     90
# AI_Training_Hours              80
# Layoff_Risk                     3
# dtype: int64

# %%
df['AI_Usage_Hours_Per_Week'].nunique()
# Out:
# 31

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         20000 non-null  int64
#  1   Education_Level             20000 non-null  str
#  2   Years_of_Experience         20000 non-null  int64
#  3   Industry                    20000 non-null  str
#  4   Job_Role                    20000 non-null  str
#  5   Company_Size                20000 non-null  str
#  6   Job_Level                   20000 non-null  str
#  7   Routine_Task_Percentage     20000 non-null  int64
#  8   Creativity_Requirement      20000 non-null  int64
#  9   Human_Interaction_Level     20000 non-null  int64
#  10  AI_Adoption_Level           20000 non-null  str
#  11  Number_of_AI_Tools_Used     20000 non-null  int64
#  12  AI_Usage_Hours_Per_Week     20000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                           0
# Education_Level               0
# Years_of_Experience           0
# Industry                      0
# Job_Role                      0
# Company_Size                  0
# Job_Level                     0
# Routine_Task_Percentage       0
# Creativity_Requirement        0
# Human_Interaction_Level       0
# AI_Adoption_Level             0
# Number_of_AI_Tools_Used       0
# AI_Usage_Hours_Per_Week       0
# Tasks_Automated_Percentage    0
# AI_Training_Hours             0
# Layoff_Risk                   0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Age                           False
# Education_Level               False
# Years_of_Experience           False
# Industry                      False
# Job_Role                      False
# Company_Size                  False
# Job_Level                     False
# Routine_Task_Percentage       False
# Creativity_Requirement        False
# Human_Interaction_Level       False
# AI_Adoption_Level             False
# Number_of_AI_Tools_Used       False
# AI_Usage_Hours_Per_Week       False
# Tasks_Automated_Percentage    False
# AI_Training_Hours             False
# Layoff_Risk                   False
# dtype: bool

# %% [markdown]
# CONDITIONS

# %%
a = 4
if a < 0:
    print("Yomon")
elif a>0:
    print("Yaxshi")
else:
    print('Nol')
# Out:
# Yaxshi

# %% [markdown]
# CONDITION HOMEWORKS

# %%
# # Imtihondan o'tish uchun condition

# score = 95

# if 100 > score >=90:
#     print('5 baho bilan o\'tdingiz')
# elif 90 > score >=76:
#     print('4 baho bilan o\'tdingiz')
# elif 76 > score >=60:
#     print("3 baho bilan bilan o'\tdingiz")
# elif 60 > score >= 50:
#     print("2 baho afsuski o'ta olmadingiz")
# else:
#     print("Xatolik")
# Out:
# 5 baho bilan o'tdingiz

# %%
# Passport uchun condition
age = 16
if age <= 16:
    print("Passport olishingiz mumkin emas. Hali yosh ekansiz")
elif age > 100:
    print("Passport olishingiz mumkin emas. Yoshiz juda katta ekan")
else:
    print('Passport olishingiz mumkin')
# Out:
# Passport olishingiz mumkin emas. Hali yosh ekansiz
